# %% [markdown]
# # My Jupityr Notebook on IBM Watson Studio

# %% [markdown]
# __Adam Leather__
#
# Aspiring data scientist

# %% [markdown]
# _I am interested in data science because my industry collects an extremely large amount of data every day, and I want to possess the skill set to draw and present conclusions from this data in order to make my industry more efficient and sustainable_

# %% [markdown]
# ### My code shows the sum of "100+100"

# %%
100 + 100
# Out:
# 200

# %% [markdown]
# <u> Primary Colours </u>
#
# 1. Red
# 2. Blue
# 3. Yellow
#
# ![RYB.png](attachment:1ebe9ecb-cda3-42db-b462-26d3287207b9.png)
